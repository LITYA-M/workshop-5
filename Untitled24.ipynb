# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

# Read image
img = cv2.imread('car_plate.jpg')

# Display image
def display(img):
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(12, 8))
    plt.imshow(img)
    plt.axis('off')
    plt.show()

display(img)

# Load license plate Haar Cascade
plate_cascade = cv2.CascadeClassifier(
    'haarcascade_russian_plate_number.xml'
)

# Detect license plate and draw rectangle
def detect_plate(img):
    img_copy = img.copy()

    plates = plate_cascade.detectMultiScale(
        img_copy,
        scaleFactor=1.1,
        minNeighbors=5
    )

    for (x, y, w, h) in plates:
        cv2.rectangle(
            img_copy,
            (x, y),
            (x + w, y + h),
            (255, 0, 0),
            3
        )

    return img_copy

# Display detected plate
result = detect_plate(img)
display(result)

# Detect and blur license plate
def detect_and_blur_plate(img):
    img_copy = img.copy()

    plates = plate_cascade.detectMultiScale(
        img_copy,
        scaleFactor=1.1,
        minNeighbors=5
    )

    for (x, y, w, h) in plates:
        roi = img_copy[y:y+h, x:x+w]

        # Apply median blur
        blurred_roi = cv2.medianBlur(roi, 25)

        # Replace original ROI with blurred ROI
        img_copy[y:y+h, x:x+w] = blurred_roi

    return img_copy

# Display final result
result = detect_and_blur_plate(img)
display(result)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 18
#      14     plt.imshow(img)
#      15     plt.axis('off')
#      16     plt.show()
#      17
# ---> 18 display(img)
#      19
#      20 # Load license plate Haar Cascade
#      21 plate_cascade = cv2.CascadeClassifier(
#
# Cell In[1], line 12, in display(img)
#      11 def display(img):
# ---> 12     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      13     plt.figure(figsize=(12, 8))
#      14     plt.imshow(img)
#      15     plt.axis('off')
#
# error: OpenCV(5.0.0) D:\bld\libopencv_1783112293125\work\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
